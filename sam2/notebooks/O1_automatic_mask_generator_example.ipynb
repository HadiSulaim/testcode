# %%
# Copyright (c) Meta Platforms, Inc. and affiliates.
# Lightly adapted from https://github.com/facebookresearch/segment-anything/blob/main/notebooks/automatic_mask_generator_example.ipynb

# %% [markdown]
# # Automatically generating object masks with SAM

# %% [markdown]
# Since SAM 2 can efficiently process prompts, masks for the entire image can be generated by sampling a large number of prompts over an image.
#
# The class `SAM2AutomaticMaskGenerator` implements this capability. It works by sampling single-point input prompts in a grid over the image, from each of which SAM can predict multiple masks. Then, masks are filtered for quality and deduplicated using non-maximal suppression. Additional options allow for further improvement of mask quality and quantity, such as running prediction on multiple crops of the image or postprocessing masks to remove small disconnected regions and holes.

# %% [markdown]
# <a target="_blank" href="https://colab.research.google.com/github/facebookresearch/sam2/blob/main/notebooks/automatic_mask_generator_example.ipynb">
#   <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>
# </a>

# %% [markdown]
# ## Environment Set-up

# %% [markdown]
# If running locally using jupyter, first install `SAM 2` in your environment using the installation instructions in the repository.
#
# If running from Google Colab, set `using_colab=True` below and run the cell. In Colab, be sure to select 'GPU' under 'Edit'->'Notebook Settings'->'Hardware accelerator'. Note that it's recommended to use **A100 or L4 GPUs when running in Colab** (T4 GPUs might also work, but could be slow and might run out of memory in some cases).

# %%
using_colab = False

# %%
if using_colab:
    import torch
    import torchvision
    print("PyTorch version:", torch.__version__)
    print("Torchvision version:", torchvision.__version__)
    print("CUDA is available:", torch.cuda.is_available())
    import sys
    # !{sys.executable} -m pip install opencv-python matplotlib
    # !{sys.executable} -m pip install 'git+https://github.com/facebookresearch/sam2.git'

    # !mkdir -p images
    # !wget -P images https://raw.githubusercontent.com/facebookresearch/sam2/main/notebooks/images/cars.jpg

    # !mkdir -p ../checkpoints/
    # !wget -P ../checkpoints/ https://dl.fbaipublicfiles.com/segment_anything_2/092824/sam2.1_hiera_large.pt

# %% [markdown]
# ## Set-up

# %%
import os
# if using Apple MPS, fall back to CPU for unsupported ops
os.environ["PYTORCH_ENABLE_MPS_FALLBACK"] = "1"
import numpy as np
import torch
import matplotlib.pyplot as plt
from PIL import Image

# %%
# select the device for computation
if torch.cuda.is_available():
    device = torch.device("cuda")
elif torch.backends.mps.is_available():
    device = torch.device("mps")
else:
    device = torch.device("cpu")
print(f"using device: {device}")

if device.type == "cuda":
    # use bfloat16 for the entire notebook
    torch.autocast("cuda", dtype=torch.bfloat16).__enter__()
    # turn on tfloat32 for Ampere GPUs (https://pytorch.org/docs/stable/notes/cuda.html#tensorfloat-32-tf32-on-ampere-devices)
    if torch.cuda.get_device_properties(0).major >= 8:
        torch.backends.cuda.matmul.allow_tf32 = True
        torch.backends.cudnn.allow_tf32 = True
elif device.type == "mps":
    print(
        "\nSupport for MPS devices is preliminary. SAM 2 is trained with CUDA and might "
        "give numerically different outputs and sometimes degraded performance on MPS. "
        "See e.g. https://github.com/pytorch/pytorch/issues/84936 for a discussion."
    )
# Out:
# using device: cuda

# %%
np.random.seed(3)

def show_anns(anns, borders=True):
    if len(anns) == 0:
        return
    sorted_anns = sorted(anns, key=(lambda x: x['area']), reverse=True)
    ax = plt.gca()
    ax.set_autoscale_on(False)

    img = np.ones((sorted_anns[0]['segmentation'].shape[0], sorted_anns[0]['segmentation'].shape[1], 4))
    img[:, :, 3] = 0
    for ann in sorted_anns:
        m = ann['segmentation']
        color_mask = np.concatenate([np.random.random(3), [0.5]])
        img[m] = color_mask 
        if borders:
            import cv2
            contours, _ = cv2.findContours(m.astype(np.uint8), cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_NONE) 
            # Try to smooth contours
            contours = [cv2.approxPolyDP(contour, epsilon=0.01, closed=True) for contour in contours]
            cv2.drawContours(img, contours, -1, (0, 0, 1, 0.4), thickness=1) 

    ax.imshow(img)

# %% [markdown]
# ## Example image

# %%
image = Image.open(r'.\videos\outputsam2_street.mp4\0005.jpg')
image = np.array(image.convert("RGB"))

# %%
plt.figure(figsize=(10, 10))
plt.imshow(image)
plt.axis('off')
plt.show()

# %% [markdown]
# ## Automatic mask generation

# %% [markdown]
# To run automatic mask generation, provide a version of SAM 2 to the `SAM2AutomaticMaskGenerator` class. Set the path below to the SAM 2 checkpoint.

# %%
from sam2.build_sam import build_sam2
from sam2.automatic_mask_generator import SAM2AutomaticMaskGenerator

sam2_checkpoint = "../checkpoints/sam2.1_hiera_large.pt"
model_cfg = "configs/sam2.1/sam2.1_hiera_l.yaml"

sam2 = build_sam2(model_cfg, sam2_checkpoint, device=device, apply_postprocessing=False)

mask_generator = SAM2AutomaticMaskGenerator(sam2)

# %% [markdown]
# To generate masks, just run `generate` on an image.

# %%
masks = mask_generator.generate(image)

# %% [markdown]
# Mask generation returns a list over masks, where each mask is a dictionary containing various data about the mask. These keys are:
# * `segmentation` : the mask
# * `area` : the area of the mask in pixels
# * `bbox` : the boundary box of the mask in XYWH format
# * `predicted_iou` : the model's own prediction for the quality of the mask
# * `point_coords` : the sampled input point that generated this mask
# * `stability_score` : an additional measure of mask quality
# * `crop_box` : the crop of the image used to generate this mask in XYWH format

# %%
print(len(masks))
print(masks[0].keys())
# Out:
# 34
# dict_keys(['segmentation', 'area', 'bbox', 'predicted_iou', 'point_coords', 'stability_score', 'crop_box'])

# %% [markdown]
# Show all the masks overlayed on the image.

# %%
plt.figure(figsize=(10, 10))
plt.imshow(image)
show_anns(masks)
plt.axis('off')
plt.show()

# %% [markdown]
# ## Automatic mask generation options

# %% [markdown]
# There are several tunable parameters in automatic mask generation that control how densely points are sampled and what the thresholds are for removing low quality or duplicate masks. Additionally, generation can be automatically run on crops of the image to get improved performance on smaller objects, and post-processing can remove stray pixels and holes. Here is an example configuration that samples more masks:

# %%
mask_generator_2 = SAM2AutomaticMaskGenerator(
    model=sam2,
    points_per_side=64,
    points_per_batch=128,
    pred_iou_thresh=0.7,
    stability_score_thresh=0.92,
    stability_score_offset=0.7,
    crop_n_layers=1,
    box_nms_thresh=0.7,
    crop_n_points_downscale_factor=2,
    min_mask_region_area=25.0,
    use_m2m=True,
)

# %%
masks2 = mask_generator_2.generate(image)
# Out:
# C:\Users\hadis\Desktop\thesis clone\Thesis-implementation\segment-anything-2\sam2\sam2_image_predictor.py:431: UserWarning: cannot import name '_C' from 'sam2' (C:\Users\hadis\Desktop\thesis clone\Thesis-implementation\segment-anything-2\sam2\__init__.py)
#
# Skipping the post-processing step due to the error above. You can still use SAM 2 and it's OK to ignore the error above, although some post-processing functionality may be limited (which doesn't affect the results in most cases; see https://github.com/facebookresearch/sam2/blob/main/INSTALL.md).
#   masks = self._transforms.postprocess_masks(

# %%
plt.figure(figsize=(10, 10))
plt.imshow(image)
show_anns(masks2)
plt.axis('off')
plt.show()

# %%
masks2
# Out:
# [{'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 42287,
#   'bbox': [0.0, 0.0, 430.0, 177.0],
#   'predicted_iou': 0.98046875,
#   'point_coords': [[268.125, 11.3125]],
#   'stability_score': 0.9718539714813232,
#   'crop_box': [0.0, 0.0, 1144.0, 724.0]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 42301,
#   'bbox': [0.0, 0.0, 453.0, 253.0],
#   'predicted_iou': 0.9765625,
#   'point_coords': [[89.375, 147.0625]],
#   'stability_score': 0.9246002435684204,
#   'crop_box': [0.0, 0.0, 1144.0, 724.0]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 1584,
#   'bbox': [435.0, 0.0, 56.0, 29.0],
#   'predicted_iou': 0.9609375,
#   'point_coords': [[482.625, 11.3125]],
#   'stability_score': 0.9812147617340088,
#   'crop_box': [0.0, 0.0, 1144.0, 724.0]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 17238,
#   'bbox': [400.0, 29.0, 124.0, 305.0],
#   'predicted_iou': 0.9609375,
#   'point_coords': [[411.125, 56.5625]],
#   'stability_score': 0.9400562047958374,
#   'crop_box': [0.0, 0.0, 1144.0, 724.0]},
#  {'segmentation': array([[ True,  True,  True, ..., False, False, False],
#          [ True,  True,  True, ..., False, False, False],
#          [ True,  True,  True, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 5442,
#   'bbox': [0.0, 0.0, 199.0, 52.0],
#   'predicted_iou': 0.95703125,
#   'point_coords': [[125.125, 11.3125]],
#   'stability_score': 0.9830446839332581,
#   'crop_box': [0.0, 0.0, 1144.0, 724.0]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 4571,
#   'bbox': [786.0, 0.0, 44.0, 107.0],
#   'predicted_iou': 0.95703125,
#   'point_coords': [[804.375, 101.8125]],
#   'stability_score': 0.9696643948554993,
#   'crop_box': [0.0, 0.0, 1144.0, 724.0]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 3376,
#   'bbox': [791.0, 101.0, 97.0, 41.0],
#   'predicted_iou': 0.953125,
#   'point_coords': [[804.375, 124.4375]],
#   'stability_score': 0.9739842414855957,
#   'crop_box': [0.0, 0.0, 1144.0, 724.0]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 1469,
#   'bbox': [643.0, 18.0, 53.0, 29.0],
#   'predicted_iou': 0.94921875,
#   'point_coords': [[661.375, 33.9375]],
#   'stability_score': 0.9610477089881897,
#   'crop_box': [0.0, 0.0, 1144.0, 724.0]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 13220,
#   'bbox': [709.0, 0.0, 83.0, 181.0],
#   'predicted_iou': 0.94921875,
#   'point_coords': [[732.875, 56.5625]],
#   'stability_score': 0.9591037034988403,
#   'crop_box': [0.0, 0.0, 1144.0, 724.0]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 17237,
#   'bbox': [400.0, 27.0, 81.0, 307.0],
#   'predicted_iou': 0.94921875,
#   'point_coords': [[446.875, 260.1875]],
#   'stability_score': 0.9555341601371765,
#   'crop_box': [0.0, 0.0, 1144.0, 724.0]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 3897,
#   'bbox': [812.0, 247.0, 52.0, 153.0],
#   'predicted_iou': 0.9453125,
#   'point_coords': [[840.125, 282.8125]],
#   'stability_score': 0.9399014711380005,
#   'crop_box': [0.0, 0.0, 1144.0, 724.0]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 1534,
#   'bbox': [971.0, 31.0, 29.0, 65.0],
#   'predicted_iou': 0.94140625,
#   'point_coords': [[983.125, 56.5625]],
#   'stability_score': 0.9787096977233887,
#   'crop_box': [0.0, 0.0, 1144.0, 724.0]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 4261,
#   'bbox': [622.0, 83.0, 65.0, 87.0],
#   'predicted_iou': 0.94140625,
#   'point_coords': [[625.625, 124.4375]],
#   'stability_score': 0.9537968635559082,
#   'crop_box': [0.0, 0.0, 1144.0, 724.0]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 7970,
#   'bbox': [544.0, 180.0, 192.0, 102.0],
#   'predicted_iou': 0.93359375,
#   'point_coords': [[554.125, 260.1875]],
#   'stability_score': 0.9561166763305664,
#   'crop_box': [0.0, 0.0, 1144.0, 724.0]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 7025,
#   'bbox': [724.0, 223.0, 64.0, 179.0],
#   'predicted_iou': 0.93359375,
#   'point_coords': [[732.875, 260.1875]],
#   'stability_score': 0.9570252299308777,
#   'crop_box': [0.0, 0.0, 1144.0, 724.0]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 11494,
#   'bbox': [0.0, 315.0, 429.0, 216.0],
#   'predicted_iou': 0.93359375,
#   'point_coords': [[196.625, 418.5625]],
#   'stability_score': 0.9459436535835266,
#   'crop_box': [0.0, 0.0, 1144.0, 724.0]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 11695,
#   'bbox': [599.0, 0.0, 111.0, 168.0],
#   'predicted_iou': 0.9296875,
#   'point_coords': [[625.625, 11.3125]],
#   'stability_score': 0.9434102773666382,
#   'crop_box': [0.0, 0.0, 1144.0, 724.0]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 655,
#   'bbox': [317.0, 237.0, 29.0, 27.0],
#   'predicted_iou': 0.9296875,
#   'point_coords': [[339.625, 260.1875]],
#   'stability_score': 0.9638554453849792,
#   'crop_box': [0.0, 0.0, 1144.0, 724.0]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 1540,
#   'bbox': [428.0, 294.0, 53.0, 42.0],
#   'predicted_iou': 0.9296875,
#   'point_coords': [[446.875, 328.0625]],
#   'stability_score': 0.9588086009025574,
#   'crop_box': [0.0, 0.0, 1144.0, 724.0]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 598,
#   'bbox': [585.0, 338.0, 25.0, 30.0],
#   'predicted_iou': 0.9296875,
#   'point_coords': [[589.875, 350.6875]],
#   'stability_score': 0.9752066135406494,
#   'crop_box': [0.0, 0.0, 1144.0, 724.0]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 5309,
#   'bbox': [724.0, 242.0, 64.0, 107.0],
#   'predicted_iou': 0.92578125,
#   'point_coords': [[732.875, 260.1875]],
#   'stability_score': 0.9426543116569519,
#   'crop_box': [0.0, 0.0, 1144.0, 724.0]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 11578,
#   'bbox': [530.0, 0.0, 179.0, 162.0],
#   'predicted_iou': 0.921875,
#   'point_coords': [[697.125, 124.4375]],
#   'stability_score': 0.9406427145004272,
#   'crop_box': [0.0, 0.0, 1144.0, 724.0]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 4301,
#   'bbox': [353.0, 155.0, 45.0, 161.0],
#   'predicted_iou': 0.921875,
#   'point_coords': [[375.375, 214.9375]],
#   'stability_score': 0.9427154064178467,
#   'crop_box': [0.0, 0.0, 1144.0, 724.0]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 459,
#   'bbox': [822.0, 242.0, 22.0, 24.0],
#   'predicted_iou': 0.921875,
#   'point_coords': [[840.125, 260.1875]],
#   'stability_score': 0.9656652212142944,
#   'crop_box': [0.0, 0.0, 1144.0, 724.0]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 1525,
#   'bbox': [53.0, 287.0, 40.0, 52.0],
#   'predicted_iou': 0.921875,
#   'point_coords': [[89.375, 305.4375]],
#   'stability_score': 0.9603073000907898,
#   'crop_box': [0.0, 0.0, 1144.0, 724.0]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 3823,
#   'bbox': [990.0, 0.0, 45.0, 124.0],
#   'predicted_iou': 0.91796875,
#   'point_coords': [[1018.875, 11.3125]],
#   'stability_score': 0.9567885398864746,
#   'crop_box': [0.0, 0.0, 1144.0, 724.0]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 2167,
#   'bbox': [274.0, 202.0, 49.0, 54.0],
#   'predicted_iou': 0.91796875,
#   'point_coords': [[303.875, 214.9375]],
#   'stability_score': 0.9620424509048462,
#   'crop_box': [0.0, 0.0, 1144.0, 724.0]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 1678,
#   'bbox': [554.0, 432.0, 83.0, 30.0],
#   'predicted_iou': 0.91796875,
#   'point_coords': [[589.875, 441.1875]],
#   'stability_score': 0.9580664038658142,
#   'crop_box': [0.0, 0.0, 1144.0, 724.0]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 1242,
#   'bbox': [726.0, 158.0, 68.0, 35.0],
#   'predicted_iou': 0.9140625,
#   'point_coords': [[768.625, 169.6875]],
#   'stability_score': 0.9350547790527344,
#   'crop_box': [0.0, 0.0, 1144.0, 724.0]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 5330,
#   'bbox': [887.0, 75.0, 55.0, 149.0],
#   'predicted_iou': 0.90625,
#   'point_coords': [[911.625, 101.8125]],
#   'stability_score': 0.9471276998519897,
#   'crop_box': [0.0, 0.0, 1144.0, 724.0]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 5565,
#   'bbox': [274.0, 99.0, 72.0, 139.0],
#   'predicted_iou': 0.90625,
#   'point_coords': [[339.625, 192.3125]],
#   'stability_score': 0.9317157864570618,
#   'crop_box': [0.0, 0.0, 1144.0, 724.0]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 2261,
#   'bbox': [186.0, 350.0, 50.0, 54.0],
#   'predicted_iou': 0.90625,
#   'point_coords': [[232.375, 373.3125]],
#   'stability_score': 0.9507771730422974,
#   'crop_box': [0.0, 0.0, 1144.0, 724.0]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 5774,
#   'bbox': [10.0, 158.0, 87.0, 130.0],
#   'predicted_iou': 0.90234375,
#   'point_coords': [[53.625, 192.3125]],
#   'stability_score': 0.9226042032241821,
#   'crop_box': [0.0, 0.0, 1144.0, 724.0]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 13869,
#   'bbox': [586.0, 258.0, 216.0, 160.0],
#   'predicted_iou': 0.90234375,
#   'point_coords': [[697.125, 373.3125]],
#   'stability_score': 0.9246835708618164,
#   'crop_box': [0.0, 0.0, 1144.0, 724.0]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 3900,
#   'bbox': [887.0, 89.0, 55.0, 90.0],
#   'predicted_iou': 0.8984375,
#   'point_coords': [[911.625, 147.0625]],
#   'stability_score': 0.9511465430259705,
#   'crop_box': [0.0, 0.0, 1144.0, 724.0]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 617,
#   'bbox': [886.0, 399.0, 29.0, 25.0],
#   'predicted_iou': 0.8984375,
#   'point_coords': [[911.625, 418.5625]],
#   'stability_score': 0.9665604829788208,
#   'crop_box': [0.0, 0.0, 1144.0, 724.0]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 6623,
#   'bbox': [900.0, 0.0, 83.0, 97.0],
#   'predicted_iou': 0.89453125,
#   'point_coords': [[911.625, 56.5625]],
#   'stability_score': 0.9504132270812988,
#   'crop_box': [0.0, 0.0, 1144.0, 724.0]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 1218,
#   'bbox': [480.0, 271.0, 63.0, 45.0],
#   'predicted_iou': 0.89453125,
#   'point_coords': [[482.625, 305.4375]],
#   'stability_score': 0.9399519562721252,
#   'crop_box': [0.0, 0.0, 1144.0, 724.0]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 418,
#   'bbox': [190.0, 120.0, 19.0, 24.0],
#   'predicted_iou': 0.890625,
#   'point_coords': [[196.625, 124.4375]],
#   'stability_score': 0.9418604373931885,
#   'crop_box': [0.0, 0.0, 1144.0, 724.0]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 1513,
#   'bbox': [794.0, 142.0, 76.0, 37.0],
#   'predicted_iou': 0.890625,
#   'point_coords': [[804.375, 169.6875]],
#   'stability_score': 0.9565780758857727,
#   'crop_box': [0.0, 0.0, 1144.0, 724.0]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 5356,
#   'bbox': [301.0, 237.0, 76.0, 172.0],
#   'predicted_iou': 0.890625,
#   'point_coords': [[303.875, 282.8125]],
#   'stability_score': 0.9358047246932983,
#   'crop_box': [0.0, 0.0, 1144.0, 724.0]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 5826,
#   'bbox': [15.0, 283.0, 69.0, 151.0],
#   'predicted_iou': 0.890625,
#   'point_coords': [[17.875, 305.4375]],
#   'stability_score': 0.9394394159317017,
#   'crop_box': [0.0, 0.0, 1144.0, 724.0]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 7369,
#   'bbox': [828.0, 0.0, 72.0, 131.0],
#   'predicted_iou': 0.88671875,
#   'point_coords': [[875.875, 33.9375]],
#   'stability_score': 0.9329856634140015,
#   'crop_box': [0.0, 0.0, 1144.0, 724.0]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 415,
#   'bbox': [263.0, 97.0, 19.0, 24.0],
#   'predicted_iou': 0.88671875,
#   'point_coords': [[268.125, 101.8125]],
#   'stability_score': 0.955294132232666,
#   'crop_box': [0.0, 0.0, 1144.0, 724.0]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 1310,
#   'bbox': [631.0, 159.0, 56.0, 33.0],
#   'predicted_iou': 0.88671875,
#   'point_coords': [[661.375, 169.6875]],
#   'stability_score': 0.9404318928718567,
#   'crop_box': [0.0, 0.0, 1144.0, 724.0]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 456,
#   'bbox': [815.0, 242.0, 29.0, 43.0],
#   'predicted_iou': 0.88671875,
#   'point_coords': [[840.125, 260.1875]],
#   'stability_score': 0.9320594668388367,
#   'crop_box': [0.0, 0.0, 1144.0, 724.0]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 1249,
#   'bbox': [973.0, 503.0, 66.0, 32.0],
#   'predicted_iou': 0.88671875,
#   'point_coords': [[1018.875, 509.0625]],
#   'stability_score': 0.9303944110870361,
#   'crop_box': [0.0, 0.0, 1144.0, 724.0]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 5162,
#   'bbox': [900.0, 0.0, 82.0, 68.0],
#   'predicted_iou': 0.8828125,
#   'point_coords': [[911.625, 56.5625]],
#   'stability_score': 0.9408551454544067,
#   'crop_box': [0.0, 0.0, 1144.0, 724.0]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 18672,
#   'bbox': [457.0, 0.0, 85.0, 313.0],
#   'predicted_iou': 0.8828125,
#   'point_coords': [[518.375, 214.9375]],
#   'stability_score': 0.9360319972038269,
#   'crop_box': [0.0, 0.0, 1144.0, 724.0]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 623,
#   'bbox': [858.0, 498.0, 21.0, 39.0],
#   'predicted_iou': 0.8828125,
#   'point_coords': [[875.875, 509.0625]],
#   'stability_score': 0.9557662010192871,
#   'crop_box': [0.0, 0.0, 1144.0, 724.0]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 2677,
#   'bbox': [219.0, 242.0, 42.0, 82.0],
#   'predicted_iou': 0.87890625,
#   'point_coords': [[232.375, 260.1875]],
#   'stability_score': 0.9409634470939636,
#   'crop_box': [0.0, 0.0, 1144.0, 724.0]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 903,
#   'bbox': [72.0, 331.0, 24.0, 55.0],
#   'predicted_iou': 0.87890625,
#   'point_coords': [[89.375, 350.6875]],
#   'stability_score': 0.9472551345825195,
#   'crop_box': [0.0, 0.0, 1144.0, 724.0]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 1222,
#   'bbox': [900.0, 175.0, 32.0, 49.0],
#   'predicted_iou': 0.875,
#   'point_coords': [[911.625, 192.3125]],
#   'stability_score': 0.9404289126396179,
#   'crop_box': [0.0, 0.0, 1144.0, 724.0]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 391,
#   'bbox': [281.0, 88.0, 27.0, 19.0],
#   'predicted_iou': 0.87109375,
#   'point_coords': [[303.875, 101.8125]],
#   'stability_score': 0.935960590839386,
#   'crop_box': [0.0, 0.0, 1144.0, 724.0]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 3804,
#   'bbox': [118.0, 173.0, 57.0, 90.0],
#   'predicted_iou': 0.87109375,
#   'point_coords': [[160.875, 237.5625]],
#   'stability_score': 0.9254297018051147,
#   'crop_box': [0.0, 0.0, 1144.0, 724.0]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 1585,
#   'bbox': [4.0, 201.0, 45.0, 46.0],
#   'predicted_iou': 0.8671875,
#   'point_coords': [[17.875, 237.5625]],
#   'stability_score': 0.9531153440475464,
#   'crop_box': [0.0, 0.0, 1144.0, 724.0]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 462,
#   'bbox': [747.0, 222.0, 22.0, 22.0],
#   'predicted_iou': 0.86328125,
#   'point_coords': [[768.625, 237.5625]],
#   'stability_score': 0.9596602916717529,
#   'crop_box': [0.0, 0.0, 1144.0, 724.0]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 1530,
#   'bbox': [741.0, 340.0, 31.0, 63.0],
#   'predicted_iou': 0.86328125,
#   'point_coords': [[768.625, 350.6875]],
#   'stability_score': 0.9321607947349548,
#   'crop_box': [0.0, 0.0, 1144.0, 724.0]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 2156,
#   'bbox': [903.0, 45.0, 72.0, 52.0],
#   'predicted_iou': 0.859375,
#   'point_coords': [[947.375, 56.5625]],
#   'stability_score': 0.94046550989151,
#   'crop_box': [0.0, 0.0, 1144.0, 724.0]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 485,
#   'bbox': [332.0, 74.0, 24.0, 24.0],
#   'predicted_iou': 0.859375,
#   'point_coords': [[339.625, 79.1875]],
#   'stability_score': 0.9453441500663757,
#   'crop_box': [0.0, 0.0, 1144.0, 724.0]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 2107,
#   'bbox': [828.0, 0.0, 23.0, 106.0],
#   'predicted_iou': 0.859375,
#   'point_coords': [[840.125, 79.1875]],
#   'stability_score': 0.9386247992515564,
#   'crop_box': [0.0, 0.0, 1144.0, 724.0]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 781,
#   'bbox': [268.0, 417.0, 19.0, 51.0],
#   'predicted_iou': 0.859375,
#   'point_coords': [[268.125, 441.1875]],
#   'stability_score': 0.9429280161857605,
#   'crop_box': [0.0, 0.0, 1144.0, 724.0]},
#  {'segmentation': array([[ True,  True,  True, ..., False, False, False],
#          [ True,  True,  True, ..., False, False, False],
#          [ True,  True,  True, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 1825,
#   'bbox': [0.0, 0.0, 115.0, 29.0],
#   'predicted_iou': 0.84765625,
#   'point_coords': [[53.625, 11.3125]],
#   'stability_score': 0.9471153616905212,
#   'crop_box': [0.0, 0.0, 1144.0, 724.0]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 365,
#   'bbox': [906.0, 74.0, 22.0, 20.0],
#   'predicted_iou': 0.84765625,
#   'point_coords': [[911.625, 79.1875]],
#   'stability_score': 0.9518716335296631,
#   'crop_box': [0.0, 0.0, 1144.0, 724.0]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 987,
#   'bbox': [5.0, 201.0, 33.0, 35.0],
#   'predicted_iou': 0.84765625,
#   'point_coords': [[17.875, 214.9375]],
#   'stability_score': 0.9378640651702881,
#   'crop_box': [0.0, 0.0, 1144.0, 724.0]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 361,
#   'bbox': [9.0, 181.0, 18.0, 23.0],
#   'predicted_iou': 0.84375,
#   'point_coords': [[17.875, 192.3125]],
#   'stability_score': 0.9312169551849365,
#   'crop_box': [0.0, 0.0, 1144.0, 724.0]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 2421,
#   'bbox': [229.0, 318.0, 45.0, 68.0],
#   'predicted_iou': 0.84375,
#   'point_coords': [[268.125, 350.6875]],
#   'stability_score': 0.9259848594665527,
#   'crop_box': [0.0, 0.0, 1144.0, 724.0]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 3277,
#   'bbox': [113.0, 288.0, 55.0, 127.0],
#   'predicted_iou': 0.84375,
#   'point_coords': [[160.875, 395.9375]],
#   'stability_score': 0.9204812049865723,
#   'crop_box': [0.0, 0.0, 1144.0, 724.0]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 1933,
#   'bbox': [192.0, 276.0, 33.0, 73.0],
#   'predicted_iou': 0.828125,
#   'point_coords': [[196.625, 328.0625]],
#   'stability_score': 0.9317048788070679,
#   'crop_box': [0.0, 0.0, 1144.0, 724.0]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 342,
#   'bbox': [331.0, 456.0, 20.0, 22.0],
#   'predicted_iou': 0.82421875,
#   'point_coords': [[339.625, 463.8125]],
#   'stability_score': 0.9293785095214844,
#   'crop_box': [0.0, 0.0, 1144.0, 724.0]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 1539,
#   'bbox': [1022.0, 0.0, 35.0, 94.0],
#   'predicted_iou': 0.8203125,
#   'point_coords': [[1054.625, 33.9375]],
#   'stability_score': 0.9370276927947998,
#   'crop_box': [0.0, 0.0, 1144.0, 724.0]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 2307,
#   'bbox': [989.0, 2.0, 46.0, 65.0],
#   'predicted_iou': 0.8203125,
#   'point_coords': [[1018.875, 56.5625]],
#   'stability_score': 0.9348006844520569,
#   'crop_box': [0.0, 0.0, 1144.0, 724.0]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 2152,
#   'bbox': [363.0, 312.0, 67.0, 55.0],
#   'predicted_iou': 0.80859375,
#   'point_coords': [[375.375, 350.6875]],
#   'stability_score': 0.9254797101020813,
#   'crop_box': [0.0, 0.0, 1144.0, 724.0]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 316,
#   'bbox': [866.0, 605.0, 23.0, 19.0],
#   'predicted_iou': 0.80078125,
#   'point_coords': [[875.875, 622.1875]],
#   'stability_score': 0.9449541568756104,
#   'crop_box': [0.0, 0.0, 1144.0, 724.0]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 428,
#   'bbox': [981.0, 0.0, 22.0, 30.0],
#   'predicted_iou': 0.796875,
#   'point_coords': [[983.125, 11.3125]],
#   'stability_score': 0.9272727370262146,
#   'crop_box': [0.0, 0.0, 1144.0, 724.0]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 304,
#   'bbox': [118.0, 345.0, 18.0, 22.0],
#   'predicted_iou': 0.796875,
#   'point_coords': [[125.125, 350.6875]],
#   'stability_score': 0.9276729822158813,
#   'crop_box': [0.0, 0.0, 1144.0, 724.0]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 371,
#   'bbox': [267.0, 475.0, 29.0, 17.0],
#   'predicted_iou': 0.78125,
#   'point_coords': [[268.125, 486.4375]],
#   'stability_score': 0.949999988079071,
#   'crop_box': [0.0, 0.0, 1144.0, 724.0]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 1180,
#   'bbox': [0.0, 443.0, 52.0, 38.0],
#   'predicted_iou': 0.74609375,
#   'point_coords': [[17.875, 463.8125]],
#   'stability_score': 0.9200652241706848,
#   'crop_box': [0.0, 0.0, 1144.0, 724.0]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 632,
#   'bbox': [256.0, 270.0, 16.0, 52.0],
#   'predicted_iou': 0.71875,
#   'point_coords': [[268.125, 282.8125]],
#   'stability_score': 0.9267175793647766,
#   'crop_box': [0.0, 0.0, 1144.0, 724.0]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 29864,
#   'bbox': [0.0, 390.0, 804.0, 544.0],
#   'predicted_iou': 0.96875,
#   'point_coords': [[625.625, 503.0625]],
#   'stability_score': 0.9470697641372681,
#   'crop_box': [0.0, 356.0, 1144.0, 724.0]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 19246,
#   'bbox': [225.0, 803.0, 108.0, 276.0],
#   'predicted_iou': 0.96484375,
#   'point_coords': [[232.375, 887.6875]],
#   'stability_score': 0.9537243843078613,
#   'crop_box': [0.0, 356.0, 1144.0, 724.0]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 9593,
#   'bbox': [0.0, 382.0, 273.0, 151.0],
# ...
#   'stability_score': 0.9451792240142822,
#   'crop_box': [0.0, 0.0, 1920.0, 1080.0]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 14215,
#   'bbox': [801.0, 124.0, 455.0, 92.0],
#   'predicted_iou': 0.921875,
#   'point_coords': [[855.0, 177.1875]],
#   'stability_score': 0.9280048608779907,
#   'crop_box': [0.0, 0.0, 1920.0, 1080.0]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 9864,
#   'bbox': [1529.0, 239.0, 140.0, 125.0],
#   'predicted_iou': 0.91796875,
#   'point_coords': [[1545.0, 295.3125]],
#   'stability_score': 0.94222092628479,
#   'crop_box': [0.0, 0.0, 1920.0, 1080.0]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 5586,
#   'bbox': [1678.0, 986.0, 197.0, 93.0],
#   'predicted_iou': 0.91796875,
#   'point_coords': [[1695.0, 1037.8125]],
#   'stability_score': 0.934497058391571,
#   'crop_box': [0.0, 0.0, 1920.0, 1080.0]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 4739,
#   'bbox': [1532.0, 239.0, 123.0, 87.0],
#   'predicted_iou': 0.9140625,
#   'point_coords': [[1575.0, 312.1875]],
#   'stability_score': 0.9522043466567993,
#   'crop_box': [0.0, 0.0, 1920.0, 1080.0]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 16696,
#   'bbox': [1506.0, 239.0, 164.0, 179.0],
#   'predicted_iou': 0.90625,
#   'point_coords': [[1605.0, 362.8125]],
#   'stability_score': 0.9212033748626709,
#   'crop_box': [0.0, 0.0, 1920.0, 1080.0]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 3433,
#   'bbox': [0.0, 439.0, 103.0, 53.0],
#   'predicted_iou': 0.89453125,
#   'point_coords': [[45.0, 447.1875]],
#   'stability_score': 0.9272778034210205,
#   'crop_box': [0.0, 0.0, 1920.0, 1080.0]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 3866,
#   'bbox': [1570.0, 1005.0, 83.0, 74.0],
#   'predicted_iou': 0.89453125,
#   'point_coords': [[1575.0, 1037.8125]],
#   'stability_score': 0.9338327050209045,
#   'crop_box': [0.0, 0.0, 1920.0, 1080.0]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 7035,
#   'bbox': [1813.0, 877.0, 92.0, 148.0],
#   'predicted_iou': 0.875,
#   'point_coords': [[1845.0, 936.5625]],
#   'stability_score': 0.9327015280723572,
#   'crop_box': [0.0, 0.0, 1920.0, 1080.0]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 343,
#   'bbox': [1767.0, 0.0, 25.0, 15.0],
#   'predicted_iou': 0.8671875,
#   'point_coords': [[1785.0, 8.4375]],
#   'stability_score': 0.9658119678497314,
#   'crop_box': [0.0, 0.0, 1920.0, 1080.0]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 8098,
#   'bbox': [347.0, 155.0, 69.0, 162.0],
#   'predicted_iou': 0.86328125,
#   'point_coords': [[405.0, 210.9375]],
#   'stability_score': 0.9243268966674805,
#   'crop_box': [0.0, 0.0, 1920.0, 1080.0]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 3901,
#   'bbox': [1732.0, 107.0, 102.0, 120.0],
#   'predicted_iou': 0.86328125,
#   'point_coords': [[1785.0, 227.8125]],
#   'stability_score': 0.9293652772903442,
#   'crop_box': [0.0, 0.0, 1920.0, 1080.0]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 2403,
#   'bbox': [770.0, 220.0, 45.0, 77.0],
#   'predicted_iou': 0.86328125,
#   'point_coords': [[795.0, 261.5625]],
#   'stability_score': 0.9435938596725464,
#   'crop_box': [0.0, 0.0, 1920.0, 1080.0]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 2967,
#   'bbox': [1629.0, 755.0, 56.0, 106.0],
#   'predicted_iou': 0.86328125,
#   'point_coords': [[1635.0, 801.5625]],
#   'stability_score': 0.9314267039299011,
#   'crop_box': [0.0, 0.0, 1920.0, 1080.0]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 2972,
#   'bbox': [1629.0, 655.0, 56.0, 206.0],
#   'predicted_iou': 0.86328125,
#   'point_coords': [[1635.0, 818.4375]],
#   'stability_score': 0.9230769276618958,
#   'crop_box': [0.0, 0.0, 1920.0, 1080.0]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 3675,
#   'bbox': [1732.0, 153.0, 99.0, 73.0],
#   'predicted_iou': 0.859375,
#   'point_coords': [[1785.0, 210.9375]],
#   'stability_score': 0.9426987171173096,
#   'crop_box': [0.0, 0.0, 1920.0, 1080.0]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 43805,
#   'bbox': [526.0, 0.0, 197.0, 280.0],
#   'predicted_iou': 0.84375,
#   'point_coords': [[585.0, 210.9375]],
#   'stability_score': 0.93772953748703,
#   'crop_box': [0.0, 0.0, 1920.0, 1080.0]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 2363,
#   'bbox': [1791.0, 601.0, 52.0, 267.0],
#   'predicted_iou': 0.83203125,
#   'point_coords': [[1815.0, 615.9375]],
#   'stability_score': 0.9280779957771301,
#   'crop_box': [0.0, 0.0, 1920.0, 1080.0]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 1429,
#   'bbox': [0.0, 319.0, 17.0, 118.0],
#   'predicted_iou': 0.8203125,
#   'point_coords': [[15.0, 396.5625]],
#   'stability_score': 0.9457417726516724,
#   'crop_box': [0.0, 0.0, 1920.0, 1080.0]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 16060,
#   'bbox': [1601.0, 617.0, 114.0, 245.0],
#   'predicted_iou': 0.8203125,
#   'point_coords': [[1695.0, 801.5625]],
#   'stability_score': 0.9469075202941895,
#   'crop_box': [0.0, 0.0, 1920.0, 1080.0]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 321,
#   'bbox': [1631.0, 843.0, 21.0, 19.0],
#   'predicted_iou': 0.81640625,
#   'point_coords': [[1635.0, 852.1875]],
#   'stability_score': 0.922848641872406,
#   'crop_box': [0.0, 0.0, 1920.0, 1080.0]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 3005,
#   'bbox': [963.0, 519.0, 47.0, 84.0],
#   'predicted_iou': 0.796875,
#   'point_coords': [[1005.0, 565.3125]],
#   'stability_score': 0.9233716726303101,
#   'crop_box': [0.0, 0.0, 1920.0, 1080.0]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 459,
#   'bbox': [1054.0, 0.0, 17.0, 28.0],
#   'predicted_iou': 0.7890625,
#   'point_coords': [[1065.0, 8.4375]],
#   'stability_score': 0.9203354120254517,
#   'crop_box': [0.0, 0.0, 1920.0, 1080.0]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 803,
#   'bbox': [1434.0, 184.0, 47.0, 24.0],
#   'predicted_iou': 0.7890625,
#   'point_coords': [[1455.0, 194.0625]],
#   'stability_score': 0.9267706871032715,
#   'crop_box': [0.0, 0.0, 1920.0, 1080.0]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 1312,
#   'bbox': [1821.0, 472.0, 37.0, 44.0],
#   'predicted_iou': 0.77734375,
#   'point_coords': [[1845.0, 497.8125]],
#   'stability_score': 0.9207630157470703,
#   'crop_box': [0.0, 0.0, 1920.0, 1080.0]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 979,
#   'bbox': [1153.0, 0.0, 43.0, 52.0],
#   'predicted_iou': 0.76953125,
#   'point_coords': [[1155.0, 8.4375]],
#   'stability_score': 0.9427443146705627,
#   'crop_box': [0.0, 0.0, 1920.0, 1080.0]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 279,
#   'bbox': [1806.0, 873.0, 18.0, 17.0],
#   'predicted_iou': 0.73828125,
#   'point_coords': [[1815.0, 885.9375]],
#   'stability_score': 0.931034505367279,
#   'crop_box': [0.0, 0.0, 1920.0, 1080.0]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 250,
#   'bbox': [1483.0, 35.0, 17.0, 18.0],
#   'predicted_iou': 0.71484375,
#   'point_coords': [[1485.0, 42.1875]],
#   'stability_score': 0.9221789836883545,
#   'crop_box': [0.0, 0.0, 1920.0, 1080.0]}]

# %%
import numpy as np

# Define the target point
target_point = [541.0, 294.0]

# Find the mask with the closest matching point coordinates
selected_mask_by_point = next(
    (mask for mask in masks2 if np.allclose(mask['point_coords'][0], target_point, atol=1e-2)),
    None
)

# Print the selected mask
if selected_mask_by_point:
    print("Selected Mask:", selected_mask_by_point)
else:
    print("No mask found for the given point coordinates.")
# Out:
# No mask found for the given point coordinates.

# %%
import matplotlib.pyplot as plt

# Define the target point (x, y)
target_point = [890, 485]  # Replace with your desired point

# Check if the target point is inside any mask
selected_mask = next(
    (mask for mask in masks2 if mask['segmentation'][int(target_point[1]), int(target_point[0])]),
    None
)

# Plot the result
if selected_mask:
    print("The target point is inside a mask!")
    print("Selected Mask Details:")
    print(f"Area: {selected_mask['area']}")
    print(f"Bounding Box: {selected_mask['bbox']}")
    print(f"Predicted IoU: {selected_mask['predicted_iou']}")
    print(f"Stability Score: {selected_mask['stability_score']}")

    # Plot the image, mask, and point
    plt.figure(figsize=(10, 10))
    plt.imshow(image)  # Assuming 'image' is your original image
    plt.imshow(selected_mask['segmentation'], cmap='jet', alpha=0.6)  # Overlay the mask
    plt.scatter(target_point[0], target_point[1], color='red', s=50, label='Target Point')  # Plot the point
    plt.title("Mask Containing the Target Point")
    plt.legend()
    plt.axis('off')
    plt.show()
else:
    print("The target point is not inside any mask.")
# Out:
# The target point is inside a mask!
# Selected Mask Details:
# Area: 21912
# Bounding Box: [859.0, 399.0, 151.0, 251.0]
# Predicted IoU: 0.9296875
# Stability Score: 0.9451792240142822
